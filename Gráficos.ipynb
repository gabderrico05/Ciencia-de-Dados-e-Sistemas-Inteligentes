# %% [markdown]
# <a href="https://colab.research.google.com/github/gabderrico05/Ciencia-de-Dados-e-Sistemas-Inteligentes/blob/main/Gr%C3%A1ficos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dados = { "sexo": ["F", "M","F", "F","F", "M"],
         "bairro": ["Belvedere", "Belvedere", "Savassi", "Anchieta", None, "Savassi"],
          "valor": [150.00, 35.00, 80.00, 250.00, 9.90, 25.00],
          "cartao": ["Master", "Visa", "Visa", "Amex", "Elo", "Master"]
          }
id_clientes = [1, 2, 3, 4, 5, 6]


vendas = pd.DataFrame(dados, index=id_clientes)

# %%
print("Dominio dos atributos categóricos")
print("---------------------------------")
print("sexo: ", vendas['sexo'].unique())
print("bairro: ", vendas['bairro'].unique())
print("cartao: ", vendas['cartao'].unique())
# Out:
# Dominio dos atributos categóricos
# ---------------------------------
# sexo:  ['F' 'M']
# bairro:  ['Belvedere' 'Savassi' 'Anchieta' None]
# cartao:  ['Master' 'Visa' 'Amex' 'Elo']

# %%
print("Tabela de frequência")
print("--------------------")
print("\n1 - sexo")
print(vendas['sexo'].value_counts())
print("\n2 - bairro")
print(vendas['bairro'].value_counts())
print("\n3 - cartao")
print(vendas['cartao'].value_counts())
# Out:
# Tabela de frequência
# --------------------
#
# 1 - sexo
# sexo
# F    4
# M    2
# Name: count, dtype: int64
#
# 2 - bairro
# bairro
# Belvedere    2
# Savassi      2
# Anchieta     1
# Name: count, dtype: int64
#
# 3 - cartao
# cartao
# Master    2
# Visa      2
# Amex      1
# Elo       1
# Name: count, dtype: int64

# %%
grupo_valor_bairro = vendas['valor'].groupby(vendas['bairro'])
## duas formas diferentes de agrupamento
grupo_valor_bairro1 = vendas.groupby('bairro')['valor']

print(grupo_valor_bairro.count())
print(grupo_valor_bairro.sum())
print(grupo_valor_bairro.mean())
# Out:
# bairro
# Anchieta     1
# Belvedere    2
# Savassi      2
# Name: valor, dtype: int64
# bairro
# Anchieta     250.0
# Belvedere    185.0
# Savassi      105.0
# Name: valor, dtype: float64
# bairro
# Anchieta     250.0
# Belvedere     92.5
# Savassi       52.5
# Name: valor, dtype: float64

# %%
import matplotlib.pyplot as plt

df = pd.DataFrame({"x": list(range(1,11))})
df["y"] = (df.x *2) + 3
lines = df.plot.line(x="x", y="y", legend=False)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

dados = {"óleo de soja": [71.15, 66.93, 67.91, 67.66],
         "melancia": [10.52, 15.68, 14.95, 36.23],
         "frango congelado": [47.17, 23.68, 38.36, 17.08],}

df = pd.DataFrame(dados, index=[3,6,9,12])

lines =df.plot(kind="line",
               style=[".-","+-","*-"],
               ylim=(0,100),xlim=(3,12))

plt.show()

# %%
df = pd.DataFrame({"mulheres": [40, 10, 30],
                  "homens": [20, 30, 50]},
                  index=["teatro", "escultura", "pintura"])
barras = df.plot(kind="bar", color=["orange", "green"])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
                  "tempo": [4,5,1,7,7,8,6,6,5,
                            2,5,8,7,1,6,3,4,8,
                            5,7,4,6,3,6,2,6,8]
                  })

hist = df.plot(kind="hist", bins=3)
plt.show()

# %%
boxplot = df.boxplot(column=["tempo"], showmeans=True)
df = pd.DataFrame({
      "tempo": [4,5,1,7,7,8,6,6,5,
                2,5,8,7,1,6,3,4,8,
                5,7,4,6,3,6,2,6,18]
                })

plt.show()

# %%
# estudando a base de dados Flags

import pandas as pd
from google.colab import drive
drive.mount('/content/drive')


# importando os dados
flags = pd.read_csv("/content/drive/MyDrive/CDSI/Fonte_de_dados/flags.csv")

flags
# Out:
# Mounted at /content/drive
#                name  landmass  zone  area  population  language  religion  \
# 0       Afghanistan         5     1   648          16        10         2
# 1           Albania         3     1    29           3         6         6
# 2           Algeria         4     1  2388          20         8         2
# 3    American-Samoa         6     3     0           0         1         1
# 4           Andorra         3     1     0           0         6         0
# ..              ...       ...   ...   ...         ...       ...       ...
# 189   Western-Samoa         6     3     3           0         1         1
# 190      Yugoslavia         3     1   256          22         6         6
# 191           Zaire         4     2   905          28        10         5
# 192          Zambia         4     2   753           6        10         5
# 193        Zimbabwe         4     2   391           8        10         5
#
#      bars  stripes  colours  ...  saltires  quarters  sunstars  crescent  \
# 0       0        3        5  ...         0         0         1         0
# 1       0        0        3  ...         0         0         1         0
# 2       2        0        3  ...         0         0         1         1
# 3       0        0        5  ...         0         0         0         0
# 4       3        0        3  ...         0         0         0         0
# ..    ...      ...      ...  ...       ...       ...       ...       ...
# 189     0        0        3  ...         0         1         5         0
# 190     0        3        4  ...         0         0         1         0
# 191     0        0        4  ...         0         0         0         0
# 192     3        0        4  ...         0         0         0         0
# 193     0        7        5  ...         0         0         1         0
#
#      triangle  icon  animate text  topleft  botright
# 0           0     1        0    0    black     green
# 1           0     0        1    0      red       red
# 2           0     0        0    0    green     white
# 3           1     1        1    0     blue       red
# 4           0     0        0    0     blue       red
# ..        ...   ...      ...  ...      ...       ...
# 189         0     0        0    0     blue       red
# 190         0     0        0    0     blue       red
# 191         0     1        1    0    green     green
# 192         0     0        1    0    green     brown
# 193         1     1        1    0    green     green
#
# [194 rows x 30 columns]

# %%
# obtendo as propriedades basicas de cada atributo

i = 0
for c in flags.columns:
  i += 1
  att = flags[c]
  att_dtype = att.dtype
  att_tam_dominio = att.unique().size
  att_tem_nulo = any(att.isnull())
  if(att_tam_dominio < 0):
    print("("+str(i)+") atributo: ", c, "\t",
          "dtype: ", att_dtype, "\t",
          "nulos: ", att_tem_nulo, "\n",
          "dominio: ", att.unique())
  else:
       if(att_dtype == "object"):
        print("("+str(i)+") atributo: ", c, "\t",
              "dtype: ", att_dtype, "\t",
              "nulos: ", att_tem_nulo, "\n",
              "dominio (primeiros elementos): ", att.unique()[0:8])
       else:
        print("("+str(i)+") atributo: ", c, "\t",
              "dtype: ", att_dtype, "\t",
              "nulos: ", att_tem_nulo, "\n",
              "min: ", att.min(), "\t",
              "max: ", att.max(), "\t",
              "media: ", round(att.mean(),2), "\t",
              "desvio padrão: ", round(att.std(),2))
# Out:
# (1) atributo:  name 	 dtype:  object 	 nulos:  False
#  dominio (primeiros elementos):  ['Afghanistan' 'Albania' 'Algeria' 'American-Samoa' 'Andorra' 'Angola'
#  'Anguilla' 'Antigua-Barbuda']
# (2) atributo:  landmass 	 dtype:  int64 	 nulos:  False
#  min:  1 	 max:  6 	 media:  3.57 	 desvio padrão:  1.55
# (3) atributo:  zone 	 dtype:  int64 	 nulos:  False
#  min:  1 	 max:  4 	 media:  2.21 	 desvio padrão:  1.31
# (4) atributo:  area 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  22402 	 media:  700.05 	 desvio padrão:  2170.93
# (5) atributo:  population 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1008 	 media:  23.27 	 desvio padrão:  91.93
# (6) atributo:  language 	 dtype:  int64 	 nulos:  False
#  min:  1 	 max:  10 	 media:  5.34 	 desvio padrão:  3.5
# (7) atributo:  religion 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  7 	 media:  2.19 	 desvio padrão:  2.06
# (8) atributo:  bars 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  5 	 media:  0.45 	 desvio padrão:  1.04
# (9) atributo:  stripes 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  14 	 media:  1.55 	 desvio padrão:  2.33
# (10) atributo:  colours 	 dtype:  int64 	 nulos:  False
#  min:  1 	 max:  8 	 media:  3.46 	 desvio padrão:  1.3
# (11) atributo:  red 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.79 	 desvio padrão:  0.41
# (12) atributo:  green 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.47 	 desvio padrão:  0.5
# (13) atributo:  blue 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.51 	 desvio padrão:  0.5
# (14) atributo:  gold 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.47 	 desvio padrão:  0.5
# (15) atributo:  white 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.75 	 desvio padrão:  0.43
# (16) atributo:  black 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.27 	 desvio padrão:  0.44
# (17) atributo:  orange 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.13 	 desvio padrão:  0.34
# (18) atributo:  mainhue 	 dtype:  object 	 nulos:  False
#  dominio (primeiros elementos):  ['green' 'red' 'blue' 'gold' 'white' 'orange' 'black' 'brown']
# (19) atributo:  circles 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  4 	 media:  0.17 	 desvio padrão:  0.46
# (20) atributo:  crosses 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  2 	 media:  0.15 	 desvio padrão:  0.39
# (21) atributo:  saltires 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.09 	 desvio padrão:  0.29
# (22) atributo:  quarters 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  4 	 media:  0.15 	 desvio padrão:  0.44
# (23) atributo:  sunstars 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  50 	 media:  1.39 	 desvio padrão:  4.4
# (24) atributo:  crescent 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.06 	 desvio padrão:  0.23
# (25) atributo:  triangle 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.14 	 desvio padrão:  0.35
# (26) atributo:  icon 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.25 	 desvio padrão:  0.44
# (27) atributo:  animate 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.2 	 desvio padrão:  0.4
# (28) atributo:  text 	 dtype:  int64 	 nulos:  False
#  min:  0 	 max:  1 	 media:  0.08 	 desvio padrão:  0.28
# (29) atributo:  topleft 	 dtype:  object 	 nulos:  False
#  dominio (primeiros elementos):  ['black' 'red' 'green' 'blue' 'white' 'orange' 'gold']
# (30) atributo:  botright 	 dtype:  object 	 nulos:  False
#  dominio (primeiros elementos):  ['green' 'red' 'white' 'black' 'blue' 'gold' 'orange' 'brown']

# %%
df_cores =pd.DataFrame()

for c in flags.columns:
  if c in ['red', 'green', 'blue', 'gold', 'white', 'black', 'orange']:
    df_cores[c] = flags[c].value_counts()

print(df_cores)
# Out:
#      red  green  blue  gold  white  black  orange
# red
# 1    153     91    99    91    146     52      26
# 0     41    103    95   103     48    142     168

# %%
lst_cores = ['red', 'green', 'blue', 'gold', 'whitesmoke', 'black', 'orange']

df_cores.plot(kind='barh', subplots=True, figsize=(8, 25), color=lst_cores)
# Out:
# array([<Axes: title={'center': 'red'}, ylabel='red'>,
#        <Axes: title={'center': 'green'}, ylabel='red'>,
#        <Axes: title={'center': 'blue'}, ylabel='red'>,
#        <Axes: title={'center': 'gold'}, ylabel='red'>,
#        <Axes: title={'center': 'white'}, ylabel='red'>,
#        <Axes: title={'center': 'black'}, ylabel='red'>,
#        <Axes: title={'center': 'orange'}, ylabel='red'>], dtype=object)
